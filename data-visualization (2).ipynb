# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ckdisease/kidney_disease.csv

# %%
df=pd.read_csv("../input/ckdisease/kidney_disease.csv")
print("number of rows in data set are:",df.shape[0])
print("number of columns in data set are:",df.shape[1])
# Out:
# number of rows in data set are: 400
# number of columns in data set are: 26

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %% [markdown]
# 1. Heat Map

# %%
df.corr().style.format("{:.3}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
# #T_4208f188_f522_11ea_be5a_0242ac130202row0_col0,#T_4208f188_f522_11ea_be5a_0242ac130202row1_col1,#T_4208f188_f522_11ea_be5a_0242ac130202row2_col2,#T_4208f188_f522_11ea_be5a_0242ac130202row3_col3,#T_4208f188_f522_11ea_be5a_0242ac130202row4_col4,#T_4208f188_f522_11ea_be5a_0242ac130202row5_col5,#T_4208f188_f522_11ea_be5a_0242ac130202row6_col6,#T_4208f188_f522_11ea_be5a_0242ac130202row7_col7,#T_4208f188_f522_11ea_be5a_0242ac130202row8_col8,#T_4208f188_f522_11ea_be5a_0242ac130202row9_col9,#T_4208f188_f522_11ea_be5a_0242ac130202row10_col10,#T_4208f188_f522_11ea_be5a_0242ac130202row11_col11{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_4208f188_f522_11ea_be5a_0242ac130202row0_col1,#T_4208f188_f522_11ea_be5a_0242ac130202row10_col4{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_4208f188_f522_11ea_be5a_0242ac130202row0_col2,#T_4208f188_f522_11ea_be5a_0242ac130202row8_col3{
# ...

# %% [markdown]
# 2. Boxplot

# %%
fig,ax=plt.subplots(figsize=(18,12))
sns.boxplot(x="pcc",y="age",hue="ba",data=df)

# %% [markdown]
# 3. Countplot

# %%
sns.countplot(x='ba',data=df,hue='pcc',palette='BuPu',linewidth=3)

# %% [markdown]
# 4. Barplot

# %%
sns.barplot(x="bp", y="pcc", hue="ba", data=df,palette="PuBu")

# %% [markdown]
# 5. Scatterplot

# %%
sns.scatterplot(x="age", y="bp",hue="ba",data=df,palette="cool")

# %% [markdown]
# 6. LM plot

# %%
sns.lmplot(x="bp", y="al", col="pcc", hue="ba",
           data=df)

# %% [markdown]
# 7. Point plot

# %%
sns.pointplot(x = "bp",y = 'al',data = df,color = "green",alpha = .6)

# %% [markdown]
# 8. Pairplot

# %%
sns.pairplot(df,hue="ba",vars=["age","bp"],palette="husl")

# %% [markdown]
#  9. Joint plot

# %%
sns.set(style="white")
sns.jointplot(x="sg",y="age",kind="kde",color="r",data=df)

# %% [markdown]
# 10. Catplot

# %%
sns.catplot(x="sg", y="age",hue="ba", col="pcc",data=df, kind="swarm",height=5.7, aspect=.5)

# %% [markdown]
# 11. Implot

# %%
sns.lmplot(x="sg", y="age", col="ba", hue="pcc", data=df)

# %% [markdown]
# 12. Lineplot

# %%
sns.lineplot(x="sg", y="age", hue="ba", data = df)

# %% [markdown]
# 13. Relplot

# %%
sns.relplot(
    data=df,
    x="age", y="bp",
    hue="pcc", size="sg", col="ba",
    kind="line", size_order=["T1", "T2"],
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)

# %% [markdown]
# 14. Violinplot

# %%
sns.violinplot(data=df, x="age", y="bp", hue="al")

# %% [markdown]
# 15. Stripplot

# %%
sns.stripplot(x="age", y="bp",
              data=df, dodge=True, alpha=.25, zorder=1)
